# %%
import nonparametric as nonp
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.array([32, 33, 34, 35, 36, 37, 38, 39, 40, 42])
n = np.array([10, 33, 81, 161, 224, 289, 336, 369, 383, 389])

# Mr Weibull's measurements are cumulative, so let's calculate the obervations at each point.
n = np.concatenate([[n[0]], np.diff(n)])

# %%
import parametric as par

# %%
xx = par.Weibull.random(200, 10, 0.2)
weib_2p = par.Weibull.fit(xx, how='MLE')
print(weib_2p.params)
weib_2p.plot()
# Out:
# (9.273070800049462, 0.20390101324667692)

# %%
xx = par.Weibull.random(1000, 10, 3) + 100

# %%
a = par.Weibull3p.fit(xx, how='MLE')
print(a.params)
a.plot();
# Out:
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:459: RuntimeWarning: invalid value encountered in double_scalars
#   * np.exp(-((x - gamma) / alpha)**beta)
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:459: RuntimeWarning: divide by zero encountered in true_divide
#   * np.exp(-((x - gamma) / alpha)**beta)
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:459: RuntimeWarning: invalid value encountered in true_divide
#   * np.exp(-((x - gamma) / alpha)**beta)
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:521: RuntimeWarning: invalid value encountered in less
#   like[like < TINIEST] = TINIEST
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:459: RuntimeWarning: divide by zero encountered in reciprocal
#   * np.exp(-((x - gamma) / alpha)**beta)
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:459: RuntimeWarning: invalid value encountered in multiply
#   * np.exp(-((x - gamma) / alpha)**beta)
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:459: RuntimeWarning: divide by zero encountered in double_scalars
#   * np.exp(-((x - gamma) / alpha)**beta)
# /Users/DerrynKnife1/Projects/SurPyval/parametric.py:459: RuntimeWarning: invalid value encountered in power
#   * np.exp(-((x - gamma) / alpha)**beta)
# (38.50187967471413, 11.199800829879756, 71.46111487089556)
