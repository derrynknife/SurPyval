# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.optimize import minimize
# %matplotlib inline

# %%
lambda_ = lambda x : x**1.23

# %%
for j in range(0, 10):
    rvs = np.random.exponential(size=100).cumsum()
    nhpp_N = np.zeros_like(rvs)
    for i, rv in enumerate(rvs):
        fun = lambda x : (lambda_(x) - rv)**2
        res = minimize(fun, rv)
        nhpp_N[i] = res.x
    plt.step(nhpp_N, np.ones_like(nhpp_N).cumsum())
xx = np.linspace(0, 45)
plt.plot(xx, lambda_(xx), linestyle='--', color='k')
